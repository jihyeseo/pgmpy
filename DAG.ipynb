# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import networkx as nx
import numpy as np
import pandas as pd
 
from pgmpy.base import DAG

# %%
df = pd.DataFrame([[0, 3], [0, 0]])
dg = nx.DiGraph(df, latents=set([0]))
dg.adj[0][1]['weight']
# Out:
# 3

# %%
dag = DAG(df, latents=set([0]))
dag.adj[0][1]['weight']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dag = DAG(df, latents=set([0]))
#       2 dag.adj[0][1]['weight']
#
# File ~/codes2/pgmpy/pgmpy/base/DAG.py:75, in DAG.__init__(self, ebunch, latents)
#      74 def __init__(self, ebunch=None, latents=set()):
# ---> 75     super(DAG, self).__init__(ebunch)
#      76     self.latents = set(latents)
#      77     cycles = []
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
dag.adj
# Out:
# AdjacencyView({0: {1: {'weight': None}}, 1: {}})

# %%
graph = nx.DiGraph([("a", "b"), ("b", "c"), ("a", "c")], weight=3)

# %%
graph.adjacency()

# %%
adj_mat = nx.adjacency_matrix(graph, nodelist=['a','b','c'],weight="weight")

# %%
adj_mat
# Out:
# <Compressed Sparse Row sparse array of dtype 'int64'
# 	with 2 stored elements and shape (3, 3)>

# %%
d = nx.to_dict_of_dicts(graph, nodelist=['a','b','c'])

# %%
d
# Out:
# {'a': {'b': {}, 'c': {}}, 'b': {'c': {}}, 'c': {}}

# %%
G = nx.Graph()
G.add_edges_from(
    [
        (0, 1, {"weight": 1.0}),
        (1, 2, {"weight": 2.0}),
        (2, 0, {"weight": 1.0}),
    ]
)
d = nx.to_dict_of_dicts(G)

# %%
d
# Out:
# {0: {1: {'weight': 1.0}, 2: {'weight': 1.0}},
#  1: {0: {'weight': 1.0}, 2: {'weight': 2.0}},
#  2: {1: {'weight': 2.0}, 0: {'weight': 1.0}}}

# %%
nx.to_dict_of_lists(G)
# Out:
# {0: [1, 2], 1: [0, 2], 2: [1, 0]}

# %%
adj = {'a': {'b': {4}, 'c': {3}}, 'b': {'c': {2}}, 'c': {}}
graph = DAG(ebunch=adj, latents=set(['a']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 adj = {'a': {'b': {4}, 'c': {3}}, 'b': {'c': {2}}, 'c': {}}
# ----> 2 graph = DAG(ebunch=adj, latents=set(['a']))
#
# File ~/codes2/pgmpy/pgmpy/base/DAG.py:75, in DAG.__init__(self, ebunch, latents)
#      74 def __init__(self, ebunch=None, latents=set()):
# ---> 75     super(DAG, self).__init__(ebunch)
#      76     self.latents = set(latents)
#      77     cycles = []
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
dod = {'a': {'b': {"weight": 1}}}  # single edge (0,1)
G = nx.from_dict_of_dicts(dod)

# %%
G.edge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 G.edge
#
# AttributeError: 'Graph' object has no attribute 'edge'

# %%
G.adj['a']['b']
# Out:
# {'weight': 4}

# %%
G.adj
# Out:
# AdjacencyView({'a': {'b': {'weight': 4}, 'c': {'weight': 3}}, 'b': {'a': {'weight': 4}, 'c': {'weight': 2}}, 'c': {'a': {'weight': 3}, 'b': {'weight': 2}}})

# %%
G.graph.adj
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 G.graph.adj
#
# AttributeError: 'dict' object has no attribute 'adj'

# %%
G = nx.Graph(dod)

# %%
G.adj
# Out:
# AdjacencyView({'a': {'b': {'weight': 4}, 'c': {'weight': 3}}, 'b': {'a': {'weight': 4}, 'c': {'weight': 2}}, 'c': {'a': {'weight': 3}, 'b': {'weight': 2}}})

# %%
G.graph.adj
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 G.graph.adj
#
# AttributeError: 'dict' object has no attribute 'adj'

# %%
import pandas as pd
G = nx.Graph({'a': {'b': {"weight": 4}, 'c': {"weight": 3}}, 'b': {'c': {"weight": 2}}})
df = nx.to_pandas_adjacency(G)
df
# Out:
#      a    b    c
# a  0.0  4.0  3.0
# b  4.0  0.0  2.0
# c  3.0  2.0  0.0
