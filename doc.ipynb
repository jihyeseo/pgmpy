# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: kernel kernelspec migrate run troubleshoot
#
# Jupyter command `jupyter-nbextension` not found.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Get an example model
from pgmpy.utils import get_example_model
model = get_example_model("sachs")

# Plot the model
nx.draw(model)
plt.draw()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[3], line 9
#       6 model = get_example_model("sachs")
#       8 # Plot the model
# ----> 9 nx.draw(model)
#      10 plt.draw()
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:126, in draw(G, pos, ax, **kwds)
#     123 if "with_labels" not in kwds:
#     124     kwds["with_labels"] = "labels" in kwds
# --> 126 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127 ax.set_axis_off()
#     128 plt.draw_if_interactive()
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:315, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     312     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     314 draw_networkx_nodes(G, pos, **node_kwds)
# --> 315 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     316 if with_labels:
#     317     draw_networkx_labels(G, pos, **label_kwds)
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:1061, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin, hide_ticks)
#    1059     for i in range(len(edgelist)):
#    1060         arrow = fancy_arrow_factory(i)
# -> 1061         ax.add_patch(arrow)
#    1062         edge_viz_obj.append(arrow)
#    1064 # update view after drawing
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/axes/_base.py:2446, in _AxesBase.add_patch(self, p)
#    2444 if p.get_clip_path() is None:
#    2445     p.set_clip_path(self.patch)
# -> 2446 self._update_patch_limits(p)
#    2447 self._children.append(p)
#    2448 p._remove_method = self._children.remove
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/axes/_base.py:2464, in _AxesBase._update_patch_limits(self, patch)
#    2461 if (isinstance(patch, mpatches.Rectangle) and
#    2462         ((not patch.get_width()) and (not patch.get_height()))):
#    2463     return
# -> 2464 p = patch.get_path()
#    2465 # Get all vertices on the path
#    2466 # Loop through each segment to get extrema for Bezier curve sections
#    2467 vertices = []
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/patches.py:4424, in FancyArrowPatch.get_path(self)
#    4421 """Return the path of the arrow in the data coordinates."""
#    4422 # The path is generated in display coordinates, then converted back to
#    4423 # data coordinates.
# -> 4424 _path, fillable = self._get_path_in_displaycoord()
#    4425 if np.iterable(fillable):
#    4426     _path = Path.make_compound_path(*_path)
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/patches.py:4437, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4435     posB = self._convert_xy_units(self._posA_posB[1])
#    4436     (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4437     _path = self.get_connectionstyle()(posA, posB,
#    4438                                        patchA=self.patchA,
#    4439                                        patchB=self.patchB,
#    4440                                        shrinkA=self.shrinkA * dpi_cor,
#    4441                                        shrinkB=self.shrinkB * dpi_cor
#    4442                                        )
#    4443 else:
#    4444     _path = self.get_transform().transform_path(self._path_original)
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/patches.py:2837, in ConnectionStyle._Base.__call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2831 path = self.connect(posA, posB)
#    2832 path = self._clip(
#    2833     path,
#    2834     self._in_patch(patchA) if patchA else None,
#    2835     self._in_patch(patchB) if patchB else None,
#    2836 )
# -> 2837 path = self._clip(
#    2838     path,
#    2839     inside_circle(*path.vertices[0], shrinkA) if shrinkA else None,
#    2840     inside_circle(*path.vertices[-1], shrinkB) if shrinkB else None
#    2841 )
#    2842 return path
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/patches.py:2815, in ConnectionStyle._Base._clip(self, path, in_start, in_stop)
#    2813 if in_start:
#    2814     try:
# -> 2815         _, path = split_path_inout(path, in_start)
#    2816     except ValueError:
#    2817         pass
#
# File ~/miniforge3/envs/pgmpy/lib/python3.12/site-packages/matplotlib/bezier.py:359, in split_path_inout(path, inside, tolerance, reorder_inout)
#     356 from .path import Path
#     357 path_iter = path.iter_segments()
# --> 359 ctl_points, command = next(path_iter)
#     360 begin_inside = inside(ctl_points[-2:])  # true if begin point is inside
#     362 ctl_points_old = ctl_points
#
# StopIteration:
